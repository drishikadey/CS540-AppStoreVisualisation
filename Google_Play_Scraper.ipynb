# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.teladoc.members', #first app
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=250, # defaults to 100 - keeping it at 50 to match the rest
    #filter_score_with=5 # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.teladoc.members',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
print(result) #currently a list of dicts , lets convert to pd
# Out:
# [{'reviewId': '16eaa17b-648b-49fb-b6e7-fc2b1b00880f', 'userName': 'Rick Clay', 'userImage': 'https://play-lh.googleusercontent.com/a-/ACB-R5TiTymZPP5Y5li-Jpo3BhgO0e063MCadIObTZnaog', 'content': 'Always had good service and great Doctors', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '5.0.3', 'at': datetime.datetime(2023, 3, 10, 16, 23, 15), 'replyContent': None, 'repliedAt': None}, {'reviewId': '6f1e1564-c45a-456f-a852-2e93bc408695', 'userName': 'SpiritGear', 'userImage': 'https://play-lh.googleusercontent.com/a-/ACB-R5T2Q8H3BGjni4rnDbBo_wwJtSD5HVyeIh4mjgm0GQ', 'content': 'Can\'t join visit as this is the only message I get"Your request could not be complete, please log out and try again." Also the fingerprint login completely forgets it exsisting when opening the app again Edit: The app is finally working properly again no idea why it was bugging out like that so much but it\'s still a lil annoying with the finger print', 'score': 4, 'thumbsUpCount': 0, 'reviewCreatedVers
# ...

# %%
import pandas as pd
df=[]

# %%
df = pd.DataFrame(result)
df["App Name"] = "teladoc"
df = df[:250]

# %%
df['App Name'] = 'teladoc' # Add col indicator for which app it was for later analysis
df
# Out:
#                                  reviewId          userName  \
# 0    16eaa17b-648b-49fb-b6e7-fc2b1b00880f         Rick Clay
# 1    6f1e1564-c45a-456f-a852-2e93bc408695        SpiritGear
# 2    afa8c768-6da0-4d93-b800-4c39091085d3       Randy Dykes
# 3    756bade2-b179-4b9e-9a83-cc9e36996b3d    Maritza Lebron
# 4    996b69c1-a813-4fbd-b35c-8207ab19809d  Crystal Martinez
# ..                                    ...               ...
# 245  cb4c01da-d2ff-4332-84e3-0dad5419ca5d     Jennifer Mark
# 246  948eff48-bc2b-43fc-b93f-bf3c08b326ef       B Rodriguez
# 247  b6dd382f-35de-49a5-b611-96f5c39c32db      angeline Lee
# 248  f8856ebe-aa00-4aad-9094-6d977620588b    Kristina Craig
# 249  1cf15a71-9b45-44d8-9f1c-778ae78255cf    Heather Garner
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ACB-R...
# 1    https://play-lh.googleusercontent.com/a-/ACB-R...
# 2    https://play-lh.googleusercontent.com/a/AGNmyx...
# ...

# %%
df
result2=[]
result2=result

# %%
List_of_apps = ["com.zocdoc.android","com.betterhelp","com.medco.medcopharmacy","com.talkspace.talkspaceapp","com.happify.happifyinc","com.jardogs.fmhmobile","epic.mychart.android","com.ecw.healow","com.myfitnesspal.android","com.wsl.noom","com.livestrong.tracker","com.fitbit.FitbitMobile","org.iggymedia.periodtracker","com.nike.plusgps","com.onepeloton.callisto","com.popularapp.periodcalendar","com.twentythreeandme.app","com.cigna.mobile.mycigna","com.luni.android.fitnesscoach.app","com.calm.android","com.hp.pregnancy.lite","com.doctorondemand.android.patient","com.cube.arc.blood","com.goodrx","com.modernizingmedicine.patientportal","com.aligntech.myinvisalign","gov.va.mobileapp","mobi.firedepartment","com.allergan.bd.bdmobileapp","com.simplepractice.video","com.myquest","com.anthem.sydney","com.weedmaps.app.android","leafly.android"] #add more apps here , get the package name from googleplay
name_list= ["zocdoc","betterhelp","express scripts","talkspace therapy & counseling","happify","followmyhealth","mychart","healow","myfitnesspal","noom","myplate","fitbit","flo","nike run club","peloton","period tracker",                                                                                                                                                                                        "23andme","mycigna","fitnesscoach",                                                "calm","pregnancy+","drondemand","blood donor american red cross","GoodRx: Prescription Saver","APPatient",                                                            "my invisalign","va: health and benefits","pulsepoint respond",        "Alle",                              "Telehealth by SimplePractice","MyQuest for Patients","Sydney Health","Weedmaps: Cannabis, Weed & CBD","Leafly: Find Weed Near You"]
#List_of_apps = "com.betterhelp"
print("No. of apps scraped ", len(List_of_apps)+1)
print("No. of names in list  ", len(name_list)+1)
from google_play_scraper import Sort, reviews

for i in range(len(List_of_apps)):
  #print(List_of_apps[i])

  result, continuation_token = reviews(
      List_of_apps[i],
      lang='en', # defaults to 'en'
      country='us', # defaults to 'us'
      sort=Sort.NEWEST, # defaults to Sort.NEWEST
      count=250, # defaults to 100  - or does it - i can do 200 but no more than 50 in one loop 
      #filter_score_with=5 # defaults to None(means all score)
  )

  # If you pass `continuation_token` as an argument to the reviews function at this point,
  # it will crawl the items after 3 review items.

  result, _ = reviews(
      List_of_apps[i],
      continuation_token=continuation_token # defaults to None(load from the beginning)
  )
  #print(result)
  new_df = pd.DataFrame(result) #newly crawled data , converted to pandas df
  new_df["App Name"] = str(name_list[ i]) # added the app name
  print(str(List_of_apps[i])+ " has "+str(len(new_df))+" total reviews :) ")
  print()
  df = df.append(new_df[:250] , ignore_index= True) #appended to older df 
  continuation_token=None #this makes no difference
  new_df= pd.DataFrame() #rest to null
  result2 = result2+result #trying to see if result can append 200 - not possible
  print()
# Out:
# No. of apps scraped  35
# No. of names in list   35
# com.zocdoc.android has 250 total reviews :)
# <ipython-input-51-443f8bb6ec70>:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_df[:250] , ignore_index= True) #appended to older df
# com.betterhelp has 250 total reviews :)
# <ipython-input-51-443f8bb6ec70>:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_df[:250] , ignore_index= True) #appended to older df
# com.medco.medcopharmacy has 250 total reviews :)
# <ipython-input-51-443f8bb6ec70>:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_df[:250] , ignore_index= True) #appended to older df
# com.talkspace.talkspaceapp has 250 total reviews :)
# ...

# %%
df
# Out:
#                                   reviewId  \
# 0     16eaa17b-648b-49fb-b6e7-fc2b1b00880f
# 1     6f1e1564-c45a-456f-a852-2e93bc408695
# 2     afa8c768-6da0-4d93-b800-4c39091085d3
# 3     756bade2-b179-4b9e-9a83-cc9e36996b3d
# 4     996b69c1-a813-4fbd-b35c-8207ab19809d
# ...                                    ...
# 8745  45699962-5981-4893-9e16-64085019801b
# 8746  e266bf37-f447-4211-ab6b-1e06692eaf4f
# 8747  2524e4d6-cfe5-4f39-81d2-70fcfc12c7fb
# 8748  f17036b2-386f-4490-8a4b-c982935fae5c
# 8749  898d1bfa-148d-4a55-92e1-ede68cf08251
#
#                                      userName  \
# 0                                   Rick Clay
# 1                                  SpiritGear
# 2                                 Randy Dykes
# 3                              Maritza Lebron
# 4                            Crystal Martinez
# ...                                       ...
# 8745                                   Me You
# 8746                           cupid peterpan
# ...

# %%
df.to_csv("Google-Healthcare.csv")

# %%
df
# Out:
#                                   reviewId  \
# 0     6f1e1564-c45a-456f-a852-2e93bc408695
# 1     afa8c768-6da0-4d93-b800-4c39091085d3
# 2     756bade2-b179-4b9e-9a83-cc9e36996b3d
# 3     996b69c1-a813-4fbd-b35c-8207ab19809d
# 4     12ea0f0d-81f3-4052-90f4-91d809b60ebf
# ...                                    ...
# 8745  45699962-5981-4893-9e16-64085019801b
# 8746  e266bf37-f447-4211-ab6b-1e06692eaf4f
# 8747  2524e4d6-cfe5-4f39-81d2-70fcfc12c7fb
# 8748  f17036b2-386f-4490-8a4b-c982935fae5c
# 8749  898d1bfa-148d-4a55-92e1-ede68cf08251
#
#                                      userName  \
# 0                                  SpiritGear
# 1                                 Randy Dykes
# 2                              Maritza Lebron
# 3                            Crystal Martinez
# 4                                     D Jones
# ...                                       ...
# 8745                                   Me You
# 8746                           cupid peterpan
# ...

# %%
df
# Out:
#                                   reviewId  \
# 0     16eaa17b-648b-49fb-b6e7-fc2b1b00880f
# 1     6f1e1564-c45a-456f-a852-2e93bc408695
# 2     afa8c768-6da0-4d93-b800-4c39091085d3
# 3     756bade2-b179-4b9e-9a83-cc9e36996b3d
# 4     996b69c1-a813-4fbd-b35c-8207ab19809d
# ...                                    ...
# 8745  45699962-5981-4893-9e16-64085019801b
# 8746  e266bf37-f447-4211-ab6b-1e06692eaf4f
# 8747  2524e4d6-cfe5-4f39-81d2-70fcfc12c7fb
# 8748  f17036b2-386f-4490-8a4b-c982935fae5c
# 8749  898d1bfa-148d-4a55-92e1-ede68cf08251
#
#                                      userName  \
# 0                                   Rick Clay
# 1                                  SpiritGear
# 2                                 Randy Dykes
# 3                              Maritza Lebron
# 4                            Crystal Martinez
# ...                                       ...
# 8745                                   Me You
# 8746                           cupid peterpan
# ...

# %%
df.to_csv("Google-Healthcare-All.csv")
